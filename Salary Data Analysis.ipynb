# %% [markdown]
# # SALARY DATA ANALYSIS

# %%
import pandas as pd
import numpy as np

# %%
# To read the csv file
sal = pd.read_csv('Salaries.csv')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# To read the top 10 lines of the dataset
sal.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
# To read the bottom 4 lines of the dataset
sal.tail(4)
# Out:
#             Id  EmployeeName                    JobTitle  BasePay  \
# 148650  148651  Not provided                Not provided      NaN
# 148651  148652  Not provided                Not provided      NaN
# 148652  148653  Not provided                Not provided      NaN
# 148653  148654     Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148650    NaN  San Francisco     NaN
# 148651    NaN  San Francisco     NaN
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN

# %%
sal.info
# Out:
# <bound method DataFrame.info of             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %%
sal.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
# To find the average Totalpay amount
totalpay_avg = sal['TotalPay'].mean()
totalpay_avg
# Out:
# 74768.321971703

# %%
# To find the highest and lowest base pay amount.

high_basepay = sal['BasePay'].max()
low_basepay = sal['BasePay'].min()

# %%
high_basepay
# Out:
# 319275.01

# %%
low_basepay
# Out:
# -166.01

# %%
# To find the JobTitle of PATRICK GARDNER

jt = sal[sal['EmployeeName']=='PATRICK GARDNER']['JobTitle']
jt
# Out:
# 4    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
# What is the total pay benefits of CHRISTOPHER CHONG ?

cc_tpb = sal[sal['EmployeeName']=='CHRISTOPHER CHONG']['TotalPayBenefits']
cc_tpb
# Out:
# 3    332343.61
# Name: TotalPayBenefits, dtype: float64

# %%
# Highest and Lowest paid person including benefits

highest_paid_person = sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]
hpp_name = highest_paid_person = sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]['EmployeeName']
lowest_paid_person = sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]
lpp_name = sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]['EmployeeName']

# %%
highest_paid_person
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
lowest_paid_person
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
hpp_name
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
lpp_name
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
# What is the average BasePay of alll employees per year?

avg_BasePay = sal.groupby('Year')['BasePay'].mean()
avg_BasePay
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
#How many unique job titles are there?
unique_jt = sal['JobTitle'].nunique()
unique_jt
# Out:
# 2159

# %%
# what are the most common jobs

ucj = sal['JobTitle'].unique()
ucj
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
# 5 most common job title ?

no_job = sal['JobTitle'].value_counts()[0:5]

# %%
no_job
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# corelation between length of job title and TotalPayBenefits

# %%
sal[['JobTitle','TotalPayBenefits']]
# Out:
#                                               JobTitle  TotalPayBenefits
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY         567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)         538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)         335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)         326373.19
# ...                                                ...               ...
# 148649                                       Custodian              0.00
# 148650                                    Not provided              0.00
# 148651                                    Not provided              0.00
# 148652                                    Not provided              0.00
# 148653                      Counselor, Log Cabin Ranch           -618.13
#
# [148654 rows x 2 columns]

# %%
sal['Title_length'] = sal['JobTitle'].apply(len)

# %%
sal[["Title_length","TotalPayBenefits"]]
# Out:
#         Title_length  TotalPayBenefits
# 0                 46         567595.43
# 1                 31         538909.28
# 2                 31         335279.91
# 3                 36         332343.61
# 4                 44         326373.19
# ...              ...               ...
# 148649             9              0.00
# 148650            12              0.00
# 148651            12              0.00
# 148652            12              0.00
# 148653            26           -618.13
#
# [148654 rows x 2 columns]

# %%
cor = sal[["Title_length","TotalPayBenefits"]].corr()
cor
# Out:
#                   Title_length  TotalPayBenefits
# Title_length          1.000000         -0.036878
# TotalPayBenefits     -0.036878          1.000000

# %%
import seaborn as sn
sn.heatmap((cor.corr()))
# Out:
# <AxesSubplot:>

# %%
# entire data set heat map
sn.heatmap(sal.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
# comparing total pay per year using bar plot 

sn.barplot(x='Year',y='TotalPay',data=sal)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='TotalPay'>

# %%
# complete pair plotting of the data set
sn.pairplot(sal)

# %%
import matplotlib.pyplot as plt

# %%
sal["Year"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %%
sal["Year"].hist()
# Out:
# <AxesSubplot:>

# %%
sn.countplot(x='Year',data=sal)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>
